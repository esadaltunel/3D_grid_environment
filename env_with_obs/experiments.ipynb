# %%
import itertools
def space_creater(min_range, max_range, dim):
    return list(itertools.product(range(min_range,max_range), repeat=dim))
obs_space = space_creater(0, 20, 3)
obs_space

# %%
action_space = space_creater(-1, 2, 3)
action_space

# %%
import numpy as np
np.array(obs_space[0]) + np.array(action_space[0])

# %%
obs_space[0]

# %%
(0, 0, 0,) in obs_space

# %%
if True == True or True == False:
    print(True)

# %%
arr1 = np.array([3, 4, 5])
2 * (arr1)

# %%
liste =[3, 4, 5]
liste.index(4)

# %%
import numpy as np

def get_unique_list(lst):
    # Helper function to convert sublist (array + float) to a tuple
    def convert_to_tuple(sublist):
        array_as_tuple = tuple(sublist[0])  # Convert numpy array to tuple
        return (array_as_tuple, sublist[1])

    # Create a set of unique tuples
    unique_set = set(convert_to_tuple(sublist) for sublist in lst)

    # Convert back tuples to original format with numpy arrays
    unique_lst_with_arrays = [[np.array(tup[0]), tup[1]] for tup in unique_set]

    return unique_lst_with_arrays

# Example usage
lst = [
    [np.array([4, 8, 4]), np.float64(4.6)],
    [np.array([ 4, 10,  6]), np.float64(7.0)],
    [np.array([4, 8, 4]), np.float64(4.6)]
]

# Call the function to get unique list
unique_list = get_unique_list(lst)

# Display the unique list
unique_list

# %%
arr1 = np.array([4, 8, 4])
arr2 = np.array([ 4, 10,  6])
np.append(arr1, arr2)

# %%
liste = [[3], [4], [5]]
liste
# Out:
# [[3], [4], [5]]

# %%
liste.append([6])
liste
# Out:
# [[3], [4], [5], [6]]

# %%
liste.pop(0)
liste
# Out:
# [[4], [5], [6]]

# %%
from itertools import chain
flat_list = list(chain(*liste))
flat_list
# Out:
# [4, 5, 6]

# %%
from env import Env
env = Env()
env.obstacles
# Out:
# [(15, 19, 10),
#  (0, 9, 8),
#  (14, 2, 13),
#  (16, 9, 12),
#  (2, 10, 3),
#  (9, 15, 2),
#  (9, 9, 11),
#  (0, 14, 9),
#  (0, 8, 18),
#  (7, 0, 10),
#  (6, 16, 17),
#  (12, 13, 9),
#  (0, 5, 13),
#  (8, 12, 4),
#  (1, 16, 9),
#  (5, 11, 6),
#  (10, 18, 6),
#  (7, 15, 11),
#  (7, 7, 9),
#  (17, 17, 7),
#  (17, 3, 0),
#  (4, 12, 13),
#  (13, 4, 11),
#  (8, 5, 5),
#  (6, 7, 1),
#  (4, 9, 3),
#  (3, 7, 16),
#  (3, 4, 4),
#  (10, 6, 12),
#  (13, 4, 9),
#  (1, 6, 7),
#  (5, 12, 12),
#  (17, 7, 4),
#  (13, 15, 7),
#  (19, 18, 15),
#  (0, 7, 17),
#  (0, 12, 10),
#  (7, 10, 7),
#  (15, 6, 11),
#  (2, 19, 8),
#  (17, 3, 13),
#  (16, 13, 2),
#  (6, 3, 14),
#  (2, 4, 9),
#  (17, 18, 15),
#  (8, 16, 18),
#  (9, 9, 13),
#  (2, 9, 7),
#  (13, 3, 2),
#  (1, 0, 6),
#  (1, 6, 1),
#  (4, 0, 11),
#  (6, 7, 18),
#  (18, 19, 13),
#  (2, 13, 0),
#  (15, 4, 7),
#  (3, 12, 2),
#  (1, 2, 18),
#  (5, 4, 10),
#  (13, 10, 18),
#  (16, 14, 18),
#  (11, 3, 11),
#  (6, 0, 5),
#  (1, 7, 3),
#  (12, 18, 5),
#  (18, 2, 0),
#  (2, 11, 9),
#  (19, 4, 12),
#  (19, 9, 8),
#  (11, 11, 15),
#  (18, 7, 4),
#  (0, 8, 11),
#  (12, 18, 4),
#  (9, 11, 0),
#  (9, 19, 18),
#  (3, 9, 18),
#  (7, 4, 18),
#  (2, 3, 13),
#  (1, 4, 19),
#  (19, 12, 19),
#  (7, 10, 17),
#  (1, 19, 3),
#  (0, 12, 4),
#  (5, 3, 13),
#  (14, 10, 0),
#  (2, 0, 16),
#  (9, 11, 8),
#  (8, 11, 13),
#  (1, 8, 8),
#  (15, 9, 16),
#  (1, 0, 19),
#  (6, 19, 13),
#  (2, 10, 17),
#  (10, 14, 9),
#  (2, 15, 0),
#  (7, 14, 3),
#  (5, 16, 12),
#  (2, 11, 8),
#  (0, 19, 16),
#  (6, 11, 7),
#  (14, 16, 14),
#  (12, 2, 16),
#  (11, 2, 10),
#  (9, 2, 7),
#  (3, 15, 3),
#  (17, 1, 11),
#  (0, 10, 14),
#  (3, 16, 8),
#  (10, 7, 12),
#  (12, 10, 8),
#  (3, 0, 7),
#  (9, 18, 5),
#  (5, 19, 10),
#  (2, 12, 6),
#  (13, 0, 10),
#  (16, 2, 15),
#  (7, 10, 10),
#  (17, 12, 17),
#  (13, 10, 2),
#  (14, 9, 13),
#  (0, 16, 18),
#  (3, 9, 7),
#  (8, 7, 5),
#  (15, 15, 6),
#  (15, 2, 17),
#  (19, 2, 9),
#  (6, 6, 8),
#  (10, 11, 8),
#  (19, 6, 16),
#  (13, 10, 13),
#  (13, 8, 6),
#  (10, 11, 18),
#  (4, 2, 11),
#  (11, 10, 9),
#  (17, 16, 10),
#  (2, 7, 7),
#  (4, 4, 13),
#  (1, 1, 5),
#  (3, 8, 8),
#  (12, 16, 19),
#  (3, 7, 6),
#  (16, 6, 13),
#  (14, 0, 14),
#  (14, 13, 2),
#  (12, 15, 18),
#  (13, 6, 11),
#  (5, 5, 3),
#  (10, 0, 6),
#  (10, 10, 0),
#  (10, 2, 15),
#  (9, 0, 1),
#  (11, 0, 12),
#  (2, 7, 8),
#  (9, 19, 15),
#  (13, 0, 0),
#  (15, 5, 0),
#  (6, 1, 8),
#  (13, 8, 10),
#  (4, 8, 13),
#  (12, 5, 7),
#  (4, 17, 7),
#  (11, 3, 7),
#  (3, 10, 13),
#  (4, 6, 5),
#  (10, 10, 5),
#  (11, 2, 3),
#  (0, 2, 8),
#  (6, 19, 10),
#  (5, 9, 11),
#  (3, 1, 17),
#  (10, 19, 3),
#  (18, 6, 16),
#  (10, 8, 17),
#  (8, 5, 2),
#  (14, 12, 11),
#  (10, 0, 15),
#  (17, 19, 19),
#  (10, 1, 6),
#  (7, 6, 15),
#  (11, 19, 13),
#  (4, 18, 8),
#  (11, 6, 9),
#  (18, 18, 2),
#  (2, 2, 9),
#  (2, 4, 12),
#  (2, 0, 8),
#  (18, 11, 10),
#  (16, 10, 2),
#  (6, 2, 17),
#  (13, 17, 6),
#  (19, 4, 11),
#  (19, 1, 11),
#  (8, 7, 3),
#  (9, 8, 7),
#  (4, 17, 8),
#  (3, 5, 19),
#  (5, 14, 15),
#  (12, 14, 6),
#  (17, 13, 2),
#  (4, 2, 17)]

# %%
np.linalg.norm(env._agent - env._target)
# Out:
# np.float64(25.612496949731394)
